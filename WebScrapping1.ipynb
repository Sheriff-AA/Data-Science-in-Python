# %%
import pandas as pd

# %%
rick_and_morty = pd.read_html("https://en.wikipedia.org/wiki/List_of_Rick_and_Morty_episodes")

# %%
len(rick_and_morty)
# Out:
# 15

# %%
rick_and_morty[1]
# Out:
#     No.overall  No. inseason                                   Title  \
# 0            1             1                                 "Pilot"
# 1            2             2                         "Lawnmower Dog"
# 2            3             3                          "Anatomy Park"
# 3            4             4                "M. Night Shaym-Aliens!"
# 4            5             5                  "Meeseeks and Destroy"
# 5            6             6                        "Rick Potion #9"
# 6            7             7                   "Raising Gazorpazorp"
# 7            8             8                         "Rixty Minutes"
# 8            9             9       "Something Ricked This Way Comes"
# 9           10            10  "Close Rick-counters of the Rick Kind"
# 10          11            11                       "Ricksy Business"
#
#          Directed by                     Written by Original air date [3]  \
# ...
